# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import RepeatedStratifiedKFold
from numpy import mean
from numpy import std
from matplotlib import pyplot


features_for_mood = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'instrumentalness', 'liveness', 'valence', 'tempo']

# %%
df = pd.read_csv('Full_spotify_data_senior_project64.csv')
df.head()
# Out:
#                  track_id  danceability  energy  ...  popularity    year  label
# 0  6s8JOwADhfEbqGqyKshMJE         0.386   0.500  ...        42.0  2013.0    sad
# 1  4N4VmSZhReQniqoakHBEvF         0.490   0.422  ...        39.0  2012.0    sad
# 2  7ETxkXmmEjVnloAXYzNUoH         0.818   0.634  ...        47.0  2013.0    sad
# 3  5AwQir16Hh3nHBLyGuhTjU         0.601   0.599  ...        49.0  2018.0    sad
# 4  6807mPDUKTRWDWiXaXBhke         0.699   0.594  ...        43.0  2007.0    sad
#
# [5 rows x 14 columns]

# %%
df.drop(columns=['danceability', 'key', 'loudness', 'mode', 'speechiness', 'instrumentalness', 'liveness', 'tempo', 'popularity', 'year'])
# Out:
#                    track_id  energy  valence label
# 0    6s8JOwADhfEbqGqyKshMJE   0.500    0.336   sad
# 1    4N4VmSZhReQniqoakHBEvF   0.422    0.348   sad
# 2    7ETxkXmmEjVnloAXYzNUoH   0.634    0.794   sad
# 3    5AwQir16Hh3nHBLyGuhTjU   0.599    0.577   sad
# 4    6807mPDUKTRWDWiXaXBhke   0.594    0.338   sad
# ..                      ...     ...      ...   ...
# 915  0JdDnGGlycKJr0iceYnvcK   0.731    0.398   cry
# 916  127FdW4XnmqKxRKrxRj2S5   0.666    0.321   cry
# 917  3Eu82PdSTJ8whj8KFJj4au   0.576    0.272   cry
# 918  4WUMYRlZFGppQbBQTgRb5O   0.558    0.628   cry
# 919  1R0iLr5ct7KgPjgx2vFCDa   0.632    0.355   cry
#
# [920 rows x 4 columns]

# %%
df.shape
# Out:
# (920, 14)

# %%
df_aggressive=df.loc[(df['energy']>=0.5) & (df['valence']<0.5)] 
df_aggressive['label']='aggressive'
df_aggressive
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                    track_id  danceability  ...    year       label
# 0    6s8JOwADhfEbqGqyKshMJE         0.386  ...  2013.0  aggressive
# 4    6807mPDUKTRWDWiXaXBhke         0.699  ...  2007.0  aggressive
# 5    3Zkc66ctXTrpk52tRcIoef         0.657  ...  2013.0  aggressive
# 6    2osoiXSQrConE7kKdIlxin         0.444  ...  2012.0  aggressive
# 8    3zc9UfgETcTMGiazW58Klg         0.473  ...  2014.0  aggressive
# ..                      ...           ...  ...     ...         ...
# 912  4cTUjZ61DVM4159Fet6Mee         0.637  ...  2021.0  aggressive
# 915  0JdDnGGlycKJr0iceYnvcK         0.454  ...  2020.0  aggressive
# 916  127FdW4XnmqKxRKrxRj2S5         0.598  ...  2020.0  aggressive
# 917  3Eu82PdSTJ8whj8KFJj4au         0.522  ...  2017.0  aggressive
# 919  1R0iLr5ct7KgPjgx2vFCDa         0.430  ...  2020.0  aggressive
#
# [216 rows x 14 columns]

# %%
df_aggressive.rename(columns={'label':'russel_label'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_aggressive.drop(columns=['danceability', 'key', 'loudness', 'mode', 'speechiness', 'instrumentalness', 'liveness', 'tempo', 'popularity', 'year'])
# Out:
#                    track_id  energy  valence russel_label
# 0    6s8JOwADhfEbqGqyKshMJE   0.500    0.336   aggressive
# 4    6807mPDUKTRWDWiXaXBhke   0.594    0.338   aggressive
# 5    3Zkc66ctXTrpk52tRcIoef   0.565    0.462   aggressive
# 6    2osoiXSQrConE7kKdIlxin   0.649    0.310   aggressive
# 8    3zc9UfgETcTMGiazW58Klg   0.848    0.396   aggressive
# ..                      ...     ...      ...          ...
# 912  4cTUjZ61DVM4159Fet6Mee   0.659    0.370   aggressive
# 915  0JdDnGGlycKJr0iceYnvcK   0.731    0.398   aggressive
# 916  127FdW4XnmqKxRKrxRj2S5   0.666    0.321   aggressive
# 917  3Eu82PdSTJ8whj8KFJj4au   0.576    0.272   aggressive
# 919  1R0iLr5ct7KgPjgx2vFCDa   0.632    0.355   aggressive
#
# [216 rows x 4 columns]

# %%
df_aggressive.shape
# Out:
# (216, 14)

# %%
df_happy=df.loc[(df['energy']>=0.5) & (df['valence']>=0.5)] 
df_happy['label']='happy'
df_happy
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                    track_id  danceability  energy  ...  popularity    year  label
# 2    7ETxkXmmEjVnloAXYzNUoH         0.818   0.634  ...        47.0  2013.0  happy
# 3    5AwQir16Hh3nHBLyGuhTjU         0.601   0.599  ...        49.0  2018.0  happy
# 7    24VfUtHxbkCrscWC00toom         0.501   0.648  ...        51.0  2015.0  happy
# 17   4ywXyMFZ8cktvKIvJbiksy         0.753   0.649  ...        39.0  2016.0  happy
# 18   6xxBWqtAELhcSt0kY2qo5Z         0.548   0.749  ...        42.0  2017.0  happy
# ..                      ...           ...     ...  ...         ...     ...    ...
# 895  5AwQir16Hh3nHBLyGuhTjU         0.601   0.599  ...        49.0  2018.0  happy
# 898  2GQS4AkV1hCVSt0gPum44w         0.565   0.716  ...        42.0  2017.0  happy
# 900  72KOmS4Af9IEFsT87TK1VQ         0.698   0.526  ...        46.0  2017.0  happy
# 901  3armUxyNuJmexkQRA3hZSC         0.643   0.611  ...        48.0  2021.0  happy
# 918  4WUMYRlZFGppQbBQTgRb5O         0.465   0.558  ...        36.0  2020.0  happy
#
# [313 rows x 14 columns]

# %%
df_happy.rename(columns={'label':'russel_label'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_happy.drop(columns=['danceability', 'key', 'loudness', 'mode', 'speechiness', 'instrumentalness', 'liveness', 'tempo', 'popularity', 'year'])
# Out:
#                    track_id  energy  valence russel_label
# 2    7ETxkXmmEjVnloAXYzNUoH   0.634    0.794        happy
# 3    5AwQir16Hh3nHBLyGuhTjU   0.599    0.577        happy
# 7    24VfUtHxbkCrscWC00toom   0.648    0.504        happy
# 17   4ywXyMFZ8cktvKIvJbiksy   0.649    0.550        happy
# 18   6xxBWqtAELhcSt0kY2qo5Z   0.749    0.630        happy
# ..                      ...     ...      ...          ...
# 895  5AwQir16Hh3nHBLyGuhTjU   0.599    0.577        happy
# 898  2GQS4AkV1hCVSt0gPum44w   0.716    0.604        happy
# 900  72KOmS4Af9IEFsT87TK1VQ   0.526    0.608        happy
# 901  3armUxyNuJmexkQRA3hZSC   0.611    0.510        happy
# 918  4WUMYRlZFGppQbBQTgRb5O   0.558    0.628        happy
#
# [313 rows x 4 columns]

# %%
df_happy.shape
# Out:
# (313, 14)

# %%
df_relax=df.loc[(df['energy']<0.5) & (df['valence']>=0.5)] 
df_relax['label']='relax'
df_relax
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                    track_id  danceability  energy  ...  popularity    year  label
# 20   7IcfEY0IyV4fdALbwJCw3v         0.536   0.421  ...        51.0  2019.0  relax
# 51   1OlInnJssr9pXY0Ooa0SDT         0.685   0.410  ...        47.0  2017.0  relax
# 64   60hF3gZXQ33xdAXXk6tE1x         0.537   0.491  ...        49.0  2017.0  relax
# 72   7EZnNHXfzf2C9fWU9pPDfN         0.678   0.328  ...        36.0  2016.0  relax
# 80   18kwPdB3Bx8n9Mk4YsO6LT         0.662   0.438  ...         0.0  2018.0  relax
# ..                      ...           ...     ...  ...         ...     ...    ...
# 785  6dcKIbnpi1CmMXUbrrXPUx         0.556   0.462  ...        38.0  1987.0  relax
# 801  5T5YlY74jZuZVwWgFoNGJT         0.596   0.419  ...        29.0  2013.0  relax
# 806  4MnjJ8vzq5GD3b7LGrwsyc         0.655   0.352  ...        28.0  2013.0  relax
# 868  4vI3jw8Fi8fDH0gGWzttGt         0.617   0.461  ...        37.0  2019.0  relax
# 887  7w3PBr8bkIXF3GBNoERuoz         0.537   0.491  ...        34.0  2015.0  relax
#
# [107 rows x 14 columns]

# %%
df_relax.rename(columns={'label':'russel_label'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_relax.drop(columns=['danceability', 'key', 'loudness', 'mode', 'speechiness', 'instrumentalness', 'liveness', 'tempo', 'popularity', 'year'])
# Out:
#                    track_id  energy  valence russel_label
# 20   7IcfEY0IyV4fdALbwJCw3v   0.421    0.534        relax
# 51   1OlInnJssr9pXY0Ooa0SDT   0.410    0.533        relax
# 64   60hF3gZXQ33xdAXXk6tE1x   0.491    0.508        relax
# 72   7EZnNHXfzf2C9fWU9pPDfN   0.328    0.543        relax
# 80   18kwPdB3Bx8n9Mk4YsO6LT   0.438    0.514        relax
# ..                      ...     ...      ...          ...
# 785  6dcKIbnpi1CmMXUbrrXPUx   0.462    0.512        relax
# 801  5T5YlY74jZuZVwWgFoNGJT   0.419    0.521        relax
# 806  4MnjJ8vzq5GD3b7LGrwsyc   0.352    0.734        relax
# 868  4vI3jw8Fi8fDH0gGWzttGt   0.461    0.641        relax
# 887  7w3PBr8bkIXF3GBNoERuoz   0.491    0.508        relax
#
# [107 rows x 4 columns]

# %%
df_relax.shape
# Out:
# (107, 14)

# %%
df_sad=df.loc[(df['energy']<0.5) & (df['valence']<0.5)] 
df_sad['label']='sad'
df_sad
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                    track_id  danceability  energy  ...  popularity    year  label
# 1    4N4VmSZhReQniqoakHBEvF         0.490   0.422  ...        39.0  2012.0    sad
# 9    7N1mCWyLnYXfi3AXagJCNo         0.557   0.295  ...        51.0  2012.0    sad
# 11   7dfs4SVfLPVORzjmYYqorK         0.313   0.413  ...        38.0  2018.0    sad
# 13   1psb8glAxDb4DYAwnOWzm3         0.634   0.480  ...        50.0  2018.0    sad
# 14   5bipGzsqZoCEEN9It0OOXU         0.629   0.367  ...        38.0  2014.0    sad
# ..                      ...           ...     ...  ...         ...     ...    ...
# 899  4WxNfBGTaGoN5hOqXI9TFJ         0.361   0.474  ...        46.0  2014.0    sad
# 906  1dexPsihTJqDO3QCzlZXdq         0.630   0.479  ...        44.0  2020.0    sad
# 911  4XwJ7O8RGVrKAdmEhYs8kZ         0.562   0.497  ...         8.0  2008.0    sad
# 913  0nedd58OQDiAUQHEJBrvcx         0.446   0.416  ...        38.0  2018.0    sad
# 914  3JvbGjNcSnAhNemVyvXqci         0.583   0.445  ...        48.0  2019.0    sad
#
# [284 rows x 14 columns]

# %%
df_sad.rename(columns={'label':'russel_label'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_sad.drop(columns=['danceability', 'key', 'loudness', 'mode', 'speechiness', 'instrumentalness', 'liveness', 'tempo', 'popularity', 'year'])
# Out:
#                    track_id  energy  valence russel_label
# 1    4N4VmSZhReQniqoakHBEvF   0.422   0.3480          sad
# 9    7N1mCWyLnYXfi3AXagJCNo   0.295   0.1330          sad
# 11   7dfs4SVfLPVORzjmYYqorK   0.413   0.4520          sad
# 13   1psb8glAxDb4DYAwnOWzm3   0.480   0.2750          sad
# 14   5bipGzsqZoCEEN9It0OOXU   0.367   0.2910          sad
# ..                      ...     ...      ...          ...
# 899  4WxNfBGTaGoN5hOqXI9TFJ   0.474   0.2490          sad
# 906  1dexPsihTJqDO3QCzlZXdq   0.479   0.4600          sad
# 911  4XwJ7O8RGVrKAdmEhYs8kZ   0.497   0.2210          sad
# 913  0nedd58OQDiAUQHEJBrvcx   0.416   0.0661          sad
# 914  3JvbGjNcSnAhNemVyvXqci   0.445   0.3150          sad
#
# [284 rows x 4 columns]

# %%
df_sad.shape
# Out:
# (284, 14)

# %%
df_russel=pd.concat([df_aggressive, df_happy,df_relax,df_sad])
df_russel
# Out:
#                    track_id  danceability  ...    year  russel_label
# 0    6s8JOwADhfEbqGqyKshMJE         0.386  ...  2013.0    aggressive
# 4    6807mPDUKTRWDWiXaXBhke         0.699  ...  2007.0    aggressive
# 5    3Zkc66ctXTrpk52tRcIoef         0.657  ...  2013.0    aggressive
# 6    2osoiXSQrConE7kKdIlxin         0.444  ...  2012.0    aggressive
# 8    3zc9UfgETcTMGiazW58Klg         0.473  ...  2014.0    aggressive
# ..                      ...           ...  ...     ...           ...
# 899  4WxNfBGTaGoN5hOqXI9TFJ         0.361  ...  2014.0           sad
# 906  1dexPsihTJqDO3QCzlZXdq         0.630  ...  2020.0           sad
# 911  4XwJ7O8RGVrKAdmEhYs8kZ         0.562  ...  2008.0           sad
# 913  0nedd58OQDiAUQHEJBrvcx         0.446  ...  2018.0           sad
# 914  3JvbGjNcSnAhNemVyvXqci         0.583  ...  2019.0           sad
#
# [920 rows x 14 columns]

# %%
df_russel[['energy','valence','russel_label']]
# Out:
#      energy  valence russel_label
# 0     0.500   0.3360   aggressive
# 4     0.594   0.3380   aggressive
# 5     0.565   0.4620   aggressive
# 6     0.649   0.3100   aggressive
# 8     0.848   0.3960   aggressive
# ..      ...      ...          ...
# 899   0.474   0.2490          sad
# 906   0.479   0.4600          sad
# 911   0.497   0.2210          sad
# 913   0.416   0.0661          sad
# 914   0.445   0.3150          sad
#
# [920 rows x 3 columns]

# %%
df_russel['russel_label'].value_counts()
# Out:
# happy         313
# sad           284
# aggressive    216
# relax         107
# Name: russel_label, dtype: int64
